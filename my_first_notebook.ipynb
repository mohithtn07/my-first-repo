# %% [markdown]
# Hardware refers to the physical components of a computer system that can be seen and touched, such as a keyboard or monitor. Software refers to the set of instructions or programs that run on hardware to perform tasks, such as an operating system or application. For example, a CPU is hardware, while a web browser is software.
