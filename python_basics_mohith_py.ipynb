# %% [markdown]
# <a href="https://colab.research.google.com/github/mohithtn07/my-first-repo/blob/main/python_basics_mohith_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# task 1

name = "mohit"
age = 21
height = 5.73
is_student = True

print(name , age, height, is_student)

#task 2

print(f"name:{name} | age:{age} | height:{height:.2f} | student{is_student}")

# task 3

age_in_months = age * 12
age_in_days = age * 365
remainder = age % 7
age_square = age ** 2

print("Age in months:", age_in_months)
print("Age in days:", age_in_days)
print("Remainder when age is divided by 7:", remainder)
print("Age squared:", age_square)
# Out:
# mohit 21 5.73 True
# name:mohit | age:21 | height:5.73 | studentTrue
# Age in months: 252
# Age in days: 7665
# Remainder when age is divided by 7: 0
# Age squared: 441
